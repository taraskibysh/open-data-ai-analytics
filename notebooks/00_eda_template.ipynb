# %% [markdown]
# # EDA: Аналіз вихідної кореспонденції (Грудень 2025)
#
# **Мета:** Провести розвідувальний аналіз даних (EDA) реєстру вихідної кореспонденції, виявити пікові навантаження, основних стейкхолдерів та ключові теми документів.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
file_path = '../data/raw/publichna-informatsiia-vikhidni-za-gruden-2025.xlsx'

try:
    df = pd.read_excel(file_path)
    print("Дані успішно завантажено!")
    display(df.head())
    print("-" * 50)
    df.info()
except FileNotFoundError:
    print("Файл не знайдено. Перевірте шлях.")
# Out:
# Дані успішно завантажено!
#     № документа Дата\nреєстрації  \
# 0    2972/23/12       2025-12-01
# 1  2973/34/11-2       2025-12-01
# 2    2974/24/06       2025-12-01
# 3    2975/23/06       2025-12-01
# 4    2976/24/06       2025-12-01
#
#                                             Адресати  \
# 0  Міністерство культури та стратегічних комунікацій
# 1                                  ТОВ «РОЗЕТКА. УА»
# 2             Державна служба України з питань праці
# 3  Міністерство економічного розвитку і торгівлі ...
# 4             Державна служба України з питань праці
#
#                                       Короткий зміст
# 0  На заміну свого листа від 13.11.2025 № 2878/23...
# 1  Пропонуємо видалити комерційні пропозиції з ма...
# 2  Надання щотижневої інформації відповідно до по...
# 3  Надається щотижнева (станом на 01.12.2025) опе...
# 4  Щодо погашення заборгованості із заробітної пл...
# --------------------------------------------------
# ...
